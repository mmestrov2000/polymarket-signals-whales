# %% [markdown]
# # Dataset Inventory
#
# This notebook is the first execution target for the extreme-probability study.
#
# Focus:
# - inspect the local 33GB archive
# - confirm Polymarket and Kalshi file layouts
# - identify the files needed for binary market and resolution analysis

# %% [markdown]
# ## Questions to answer
#
# - Which files define markets, contracts, observations, and final resolution?
# - Which probability field should become the canonical market-priced probability for each venue?
# - Which record types should be excluded from the first pass?
