# %% [markdown]
# # Extreme Probability Analysis
#
# This notebook will compare low probability and high probability observations against realized outcomes.
#
# Primary outputs:
# - calibration gap by bucket
# - threshold-entry and tick-weighted comparisons
# - venue-level visualization for Polymarket and Kalshi

# %% [markdown]
# ## Statistical checks
#
# - compute bucket means and realized resolution frequency
# - report Wilson intervals or market-aware bootstrap summaries
# - compare low probability and high probability regions separately
